# %%
import pandas as pd
import numpy as np
import math

# %%
hnm_file_format = 'data/HnM_{}.parquet'

# %%
cats = pd.read_parquet(hnm_file_format.format('Categories'))
filters = pd.read_parquet(hnm_file_format.format('Filters'))
items = pd.read_parquet(hnm_file_format.format('Items'))
attributes = pd.read_parquet(hnm_file_format.format('FilterAttributes'))

# %%
cats[(cats['Parent_Category'].isna()) & (cats['Skip'] == False)].groupby(['Top_Category'])['Category'].count().reset_index()
# Out:
#   Top_Category  Category
# 0         Baby         5
# 1         Kids         6
# 2          Men        18
# 3        Women        23

# %%
cats.head()
# Out:
#                Category                                            URL  \
# 0         Shirts & Tops                /de_de/damen/produkte/tops.html
# 1                Basics              /de_de/damen/produkte/basics.html
# 2       Hemden & Blusen       /de_de/damen/produkte/hemden-blusen.html
# 3  Cardigans & Pullover  /de_de/damen/produkte/cardigans-pullover.html
# 4           Strickwaren         /de_de/damen/produkte/strickwaren.html
#
#    Parent_Category Top_Category   Skip
# 0              NaN        Women  False
# 1              NaN        Women  False
# 2              NaN        Women  False
# 3              NaN        Women  False
# 4              NaN        Women  False

# %%
cats[~cats['Parent_Category'].isnull()]
# Out:
#                      Category  \
# 29               Cut-Out-Tops
# 30              Bralette-Tops
# 31               Bandeau-Tops
# 32   Oberteile mit Puffärmeln
# 33      Trägertops & Tanktops
# ..                        ...
# 402                Ballerinas
# 403                   Stiefel
# 404              Gummistiefel
# 405     Sandalen & Flip-Flops
# 406                Hausschuhe
#
#                                                    URL  Parent_Category  \
# 29             /de_de/damen/produkte/tops/cut-out.html              0.0
# 30            /de_de/damen/produkte/tops/bralette.html              0.0
# 31             /de_de/damen/produkte/tops/bandeau.html              0.0
# 32          /de_de/damen/produkte/tops/puffaermel.html              0.0
# 33              /de_de/damen/produkte/tops/westen.html              0.0
# ..                                                 ...              ...
# 402      /de_de/kinder/produkte/schuhe/ballerinas.html            370.0
# 403         /de_de/kinder/produkte/schuhe/stiefel.html            370.0
# 404    /de_de/kinder/produkte/schuhe/gummistiefel.html            370.0
# 405  /de_de/kinder/produkte/schuhe/sandalen-flip-fl...            370.0
# 406      /de_de/kinder/produkte/schuhe/hausschuhe.html            370.0
#
#     Top_Category   Skip
# 29         Women  False
# 30         Women  False
# 31         Women  False
# 32         Women  False
# 33         Women  False
# ..           ...    ...
# 402         Kids  False
# 403         Kids  False
# 404         Kids  False
# 405         Kids  False
# 406         Kids  False
#
# [296 rows x 5 columns]

# %% [markdown]
# ### Creating category name which is concatenated Top Category and Category Name (for parent categories) or top_category, parent_category and category (for  child categories)

# %%
cats.merge(
    cats[cats['Parent_Category'].isnull()], 
    right_index=True, 
    left_on='Parent_Category', 
    how='left'
)
# Out:
#                 Category_x                                              URL_x  \
# 0            Shirts & Tops                    /de_de/damen/produkte/tops.html
# 1                   Basics                  /de_de/damen/produkte/basics.html
# 2          Hemden & Blusen           /de_de/damen/produkte/hemden-blusen.html
# 3     Cardigans & Pullover      /de_de/damen/produkte/cardigans-pullover.html
# 4              Strickwaren             /de_de/damen/produkte/strickwaren.html
# ..                     ...                                                ...
# 402             Ballerinas      /de_de/kinder/produkte/schuhe/ballerinas.html
# 403                Stiefel         /de_de/kinder/produkte/schuhe/stiefel.html
# 404           Gummistiefel    /de_de/kinder/produkte/schuhe/gummistiefel.html
# 405  Sandalen & Flip-Flops  /de_de/kinder/produkte/schuhe/sandalen-flip-fl...
# 406             Hausschuhe      /de_de/kinder/produkte/schuhe/hausschuhe.html
#
#      Parent_Category_x Top_Category_x  Skip_x Category_y  \
# 0                  NaN          Women   False        NaN
# 1                  NaN          Women   False        NaN
# 2                  NaN          Women   False        NaN
# 3                  NaN          Women   False        NaN
# 4                  NaN          Women   False        NaN
# ..                 ...            ...     ...        ...
# 402              370.0           Kids   False     Schuhe
# 403              370.0           Kids   False     Schuhe
# 404              370.0           Kids   False     Schuhe
# 405              370.0           Kids   False     Schuhe
# 406              370.0           Kids   False     Schuhe
#
#                                   URL_y  Parent_Category_y Top_Category_y  \
# 0                                   NaN                NaN            NaN
# 1                                   NaN                NaN            NaN
# 2                                   NaN                NaN            NaN
# 3                                   NaN                NaN            NaN
# 4                                   NaN                NaN            NaN
# ..                                  ...                ...            ...
# 402  /de_de/kinder/produkte/schuhe.html                NaN           Kids
# 403  /de_de/kinder/produkte/schuhe.html                NaN           Kids
# 404  /de_de/kinder/produkte/schuhe.html                NaN           Kids
# 405  /de_de/kinder/produkte/schuhe.html                NaN           Kids
# 406  /de_de/kinder/produkte/schuhe.html                NaN           Kids
#
#     Skip_y
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 402  False
# 403  False
# 404  False
# 405  False
# 406  False
#
# [348 rows x 10 columns]

# %%
def apply_name(row):
    if math.isnan(row['Parent_Category_x']):
        return '_'.join([row['Top_Category_x'], row['Category_x'].replace(' ', '-')])
    else:
        return '_'.join([row['Top_Category_x'], row['Category_y'].replace(' ', '-'), row['Category_x'].replace(' ', '-')])

cats['Category_Name'] = cats.merge(
    cats[cats['Parent_Category'].isnull()], 
    right_index=True, 
    left_on='Parent_Category', 
    how='left'
).apply(apply_name, axis=1)

# %%
cats[cats['Parent_Category'].isnull()]['Category_Name'].shape
# Out:
# (52,)

# %%
# adding top category name and parent category id
items = items.merge(
    cats[['Category', 'Parent_Category', 'Top_Category', 'Category_Name']], 
    how='left', 
    left_on='Category', 
    right_index=True
).drop(
    columns='Category_y'
).rename(
    columns={
        'Category_x': 'Category',
        'Category_Name': 'Sub_Category_Name'
    }
)

# %%
items.head()
# Out:
#          Code                      Name                                 URL  \
# 0  1071498001             Cut-out-Shirt  /de_de/productpage.1071498001.html
# 1  1069183001  Kurzes Shirt mit Cut-out  /de_de/productpage.1069183001.html
# 2  0985757001     Kurzshirt mit Cut-out  /de_de/productpage.0985757001.html
# 3  0985757002     Kurzshirt mit Cut-out  /de_de/productpage.0985757002.html
# 4  1069183002  Kurzes Shirt mit Cut-out  /de_de/productpage.1069183002.html
#
#                                              Img_URL Img_Ext  Category  \
# 0  //lp2.hm.com/hmgoepprod?set=source[/a2/90/a290...    .jpg      29.0
# 1  //lp2.hm.com/hmgoepprod?set=source[/12/09/1209...    .jpg      29.0
# 2  //lp2.hm.com/hmgoepprod?set=source[/68/a3/68a3...    .jpg      29.0
# 3  //lp2.hm.com/hmgoepprod?set=source[/10/22/1022...    .jpg      29.0
# 4  //lp2.hm.com/hmgoepprod?set=source[/d1/3a/d13a...    .jpg      29.0
#
#    Parent_Category Top_Category                 Sub_Category_Name
# 0              0.0        Women  Women_Shirts-&-Tops_Cut-Out-Tops
# 1              0.0        Women  Women_Shirts-&-Tops_Cut-Out-Tops
# 2              0.0        Women  Women_Shirts-&-Tops_Cut-Out-Tops
# 3              0.0        Women  Women_Shirts-&-Tops_Cut-Out-Tops
# 4              0.0        Women  Women_Shirts-&-Tops_Cut-Out-Tops

# %%
# adding name of parent category also
items = items.merge(
    cats[['Category', 'Parent_Category', 'Category_Name']], 
    left_on='Parent_Category', 
    right_index=True, 
    how='left'
).rename(
    columns={
        'Category_x': 'Category',
        'Category_y': 'Parent_Category_Name',
        'Parent_Category_x': 'Parent_Category'
}
).drop(
    columns='Parent_Category_y'
)

# %%
items.head()
# Out:
#          Code                      Name                                 URL  \
# 0  1071498001             Cut-out-Shirt  /de_de/productpage.1071498001.html
# 1  1069183001  Kurzes Shirt mit Cut-out  /de_de/productpage.1069183001.html
# 2  0985757001     Kurzshirt mit Cut-out  /de_de/productpage.0985757001.html
# 3  0985757002     Kurzshirt mit Cut-out  /de_de/productpage.0985757002.html
# 4  1069183002  Kurzes Shirt mit Cut-out  /de_de/productpage.1069183002.html
#
#                                              Img_URL Img_Ext  Category  \
# 0  //lp2.hm.com/hmgoepprod?set=source[/a2/90/a290...    .jpg      29.0
# 1  //lp2.hm.com/hmgoepprod?set=source[/12/09/1209...    .jpg      29.0
# 2  //lp2.hm.com/hmgoepprod?set=source[/68/a3/68a3...    .jpg      29.0
# 3  //lp2.hm.com/hmgoepprod?set=source[/10/22/1022...    .jpg      29.0
# 4  //lp2.hm.com/hmgoepprod?set=source[/d1/3a/d13a...    .jpg      29.0
#
#    Parent_Category Top_Category                 Sub_Category_Name  \
# 0              0.0        Women  Women_Shirts-&-Tops_Cut-Out-Tops
# 1              0.0        Women  Women_Shirts-&-Tops_Cut-Out-Tops
# 2              0.0        Women  Women_Shirts-&-Tops_Cut-Out-Tops
# 3              0.0        Women  Women_Shirts-&-Tops_Cut-Out-Tops
# 4              0.0        Women  Women_Shirts-&-Tops_Cut-Out-Tops
#
#   Parent_Category_Name        Category_Name
# 0        Shirts & Tops  Women_Shirts-&-Tops
# 1        Shirts & Tops  Women_Shirts-&-Tops
# 2        Shirts & Tops  Women_Shirts-&-Tops
# 3        Shirts & Tops  Women_Shirts-&-Tops
# 4        Shirts & Tops  Women_Shirts-&-Tops

# %%
items.groupby('Category_Name')['Code'].agg(['count', pd.Series.nunique])
# Out:
#                              count  nunique
# Category_Name
# Baby_Accessoires               136      125
# Baby_Kleidung                 1568     1075
# Baby_Outdoor                    71       63
# Baby_Schuhe                     68       68
# Kids_Accessoires               309      296
# Kids_Kleidung                 5031     4249
# Kids_Outdoor                   323      295
# Kids_Schuhe                    215      215
# Men_Accessoires                337      320
# Men_Basics                     227      227
# Men_Blazer-&-Anzüge            137       63
# Men_Cardigans-&-Pullover       146      130
# Men_Hemden                     199      160
# Men_Hoodies-&-Sweatshirts      220      220
# Men_Hosen                      278      262
# Men_Jacken-&-Mäntel            245      137
# Men_Jeans                      120      108
# Men_Nachtwäsche                 20       20
# Men_Schuhe                     131      125
# Men_Shorts                      98       76
# Men_Socken                      16       16
# Men_Sportmode                  315      240
# Men_T-Shirts                   593      449
# Men_Unterwäsche                 90       90
# Women_Accessoires              753      735
# Women_Bademode                 235      235
# Women_Basics                   671      671
# Women_Beauty                   725      669
# Women_Cardigans-&-Pullover     351      304
# Women_Hemden-&-Blusen          418      379
# Women_Hoodies-&-Sweatshirts    340      340
# Women_Hosen                    914      668
# Women_Jacken-&-Mäntel          427      305
# Women_Jeans                    681      467
# Women_Jumpsuits-&-Playsuits     44       44
# Women_Kleider                 1442      740
# Women_Nachtwäsche              260      260
# Women_Röcke                    330      155
# Women_Schuhe                   351      267
# Women_Shirts-&-Tops           1414      867
# Women_Shorts                   318      240
# Women_Socken-&-Strumpfhosen    173      160
# Women_Sportbekleidung          591      425
# Women_Unterwäsche             1432      906

# %%
items[items['Category_Name'] == 'Men_Shorts']['Code'].value_counts()
# Out:
# 0970367001    3
# 0884754012    2
# 1035209003    2
# 1035209002    2
# 0884754007    2
#              ..
# 0986789002    1
# 1045432003    1
# 1045432002    1
# 0986789004    1
# 1037875006    1
# Name: Code, Length: 76, dtype: int64

# %%
items[items['Code'] == '0970367001']
# Out:
#              Code                     Name  \
# 14973  0970367001  Cargoshorts Relaxed Fit
# 15011  0970367001  Cargoshorts Relaxed Fit
# 15030  0970367001  Cargoshorts Relaxed Fit
#
#                                       URL  \
# 14973  /de_de/productpage.0970367001.html
# 15011  /de_de/productpage.0970367001.html
# 15030  /de_de/productpage.0970367001.html
#
#                                                  Img_URL Img_Ext  Category  \
# 14973  //lp2.hm.com/hmgoepprod?set=source[/f0/41/f041...    .jpg     332.0
# 15011  //lp2.hm.com/hmgoepprod?set=source[/f0/41/f041...    .jpg     335.0
# 15030  //lp2.hm.com/hmgoepprod?set=source[/f0/41/f041...    .jpg     336.0
#
#        Parent_Category Top_Category              Sub_Category_Name  \
# 14973            243.0          Men  Men_Shorts_Kurze-Jogginghosen
# 15011            243.0          Men        Men_Shorts_Cargo-Shorts
# 15030            243.0          Men       Men_Shorts_Casual-Shorts
#
#       Parent_Category_Name Category_Name
# 14973               Shorts    Men_Shorts
# 15011               Shorts    Men_Shorts
# 15030               Shorts    Men_Shorts

# %% [markdown]
# ### Products are repeated because of different sub-categories

# %% [markdown]
# ### Keeping only relevant columns

# %%
items_u = items[['Code', 'Name', 'Img_Ext', 'Parent_Category', 'Top_Category', 'Parent_Category_Name', 'Category_Name']].drop_duplicates()

# %%
items_u['Code'].value_counts()
# Out:
# 0945068010    3
# 1003206003    3
# 1038173002    3
# 0945068019    3
# 1005708001    3
#              ..
# 0786187005    1
# 1055453004    1
# 1013097003    1
# 0888448007    1
# 0824763001    1
# Name: Code, Length: 16473, dtype: int64

# %%
items_u[items_u['Code'] == '0945068010']
# Out:
#              Code                    Name Img_Ext  Parent_Category  \
# 12269  0945068010  Sportshirt Relaxed Fit    .jpg            226.0
# 13039  0945068010  Sportshirt Relaxed Fit    .jpg            230.0
# 14710  0945068010  Sportshirt Relaxed Fit    .jpg            241.0
#
#       Top_Category   Parent_Category_Name              Category_Name
# 12269          Men  Hoodies & Sweatshirts  Men_Hoodies-&-Sweatshirts
# 13039          Men               T-Shirts               Men_T-Shirts
# 14710          Men              Sportmode              Men_Sportmode

# %% [markdown]
# Some items are also there in multiple parent categories - let's drop these products
# P.S. - Have checked separately, dropping smaller product categories first (i.e. those with <100 products) is not helping

# %%
# let's drop these products and keep only those which have a unique category assigned to them
item_cnts = items_u['Code'].value_counts()
items_to_drop = list(item_cnts[item_cnts > 1].index)

# %%
items_u = items_u[~items_u['Code'].isin(items_to_drop)].copy()

# %%
items_u.groupby('Category_Name').agg({'Code': ['count', pd.Series.nunique]})
# Out:
#                              Code
#                             count nunique
# Category_Name
# Baby_Accessoires              123     123
# Baby_Kleidung                1058    1058
# Baby_Outdoor                   55      55
# Baby_Schuhe                    67      67
# Kids_Accessoires              286     286
# Kids_Kleidung                4237    4237
# Kids_Outdoor                  268     268
# Kids_Schuhe                   198     198
# Men_Accessoires               271     271
# Men_Blazer-&-Anzüge            39      39
# Men_Cardigans-&-Pullover      130     130
# Men_Hemden                    160     160
# Men_Hoodies-&-Sweatshirts     143     143
# Men_Hosen                     174     174
# Men_Jacken-&-Mäntel            98      98
# Men_Jeans                      93      93
# Men_Nachtwäsche                20      20
# Men_Schuhe                    124     124
# Men_Shorts                     61      61
# Men_Sportmode                  55      55
# Men_T-Shirts                  244     244
# Men_Unterwäsche                90      90
# Women_Accessoires             700     700
# Women_Bademode                223     223
# Women_Basics                   27      27
# Women_Beauty                  669     669
# Women_Cardigans-&-Pullover    281     281
# Women_Hemden-&-Blusen         373     373
# Women_Hoodies-&-Sweatshirts   203     203
# Women_Hosen                   545     545
# Women_Jacken-&-Mäntel         275     275
# Women_Jeans                   466     466
# Women_Jumpsuits-&-Playsuits    39      39
# Women_Kleider                 646     646
# Women_Nachtwäsche             260     260
# Women_Röcke                   151     151
# Women_Schuhe                  266     266
# Women_Shirts-&-Tops           568     568
# Women_Shorts                  215     215
# Women_Socken-&-Strumpfhosen   126     126
# Women_Sportbekleidung         256     256
# Women_Unterwäsche             817     817

# %%
print(f"Total number of categories: {items['Category_Name'].nunique()}")
# Out:
# Total number of categories: 44

# %%
print(f"Total number of categories with more than 100 products: {np.where(items_u.groupby('Category_Name')['Code'].size().values >= 100, 1, 0).sum()}")
# Out:
# Total number of categories with more than 100 products: 31

# %% [markdown]
# ### Dropping categories with less than 100 products

# %%
cnt_of_prods = items_u.groupby('Category_Name')['Code'].count()
cats_to_keep = list(cnt_of_prods[cnt_of_prods >= 100].index)
cats_to_keep
# Out:
# ['Baby_Accessoires',
#  'Baby_Kleidung',
#  'Kids_Accessoires',
#  'Kids_Kleidung',
#  'Kids_Outdoor',
#  'Kids_Schuhe',
#  'Men_Accessoires',
#  'Men_Cardigans-&-Pullover',
#  'Men_Hemden',
#  'Men_Hoodies-&-Sweatshirts',
#  'Men_Hosen',
#  'Men_Schuhe',
#  'Men_T-Shirts',
#  'Women_Accessoires',
#  'Women_Bademode',
#  'Women_Beauty',
#  'Women_Cardigans-&-Pullover',
#  'Women_Hemden-&-Blusen',
#  'Women_Hoodies-&-Sweatshirts',
#  'Women_Hosen',
#  'Women_Jacken-&-Mäntel',
#  'Women_Jeans',
#  'Women_Kleider',
#  'Women_Nachtwäsche',
#  'Women_Röcke',
#  'Women_Schuhe',
#  'Women_Shirts-&-Tops',
#  'Women_Shorts',
#  'Women_Socken-&-Strumpfhosen',
#  'Women_Sportbekleidung',
#  'Women_Unterwäsche']

# %%
items_u = items_u[items_u['Category_Name'].isin(cats_to_keep)].copy()

# %%
items_u.groupby('Category_Name').agg({'Code': ['count', pd.Series.nunique]})
# Out:
#                              Code
#                             count nunique
# Category_Name
# Baby_Accessoires              123     123
# Baby_Kleidung                1058    1058
# Kids_Accessoires              286     286
# Kids_Kleidung                4237    4237
# Kids_Outdoor                  268     268
# Kids_Schuhe                   198     198
# Men_Accessoires               271     271
# Men_Cardigans-&-Pullover      130     130
# Men_Hemden                    160     160
# Men_Hoodies-&-Sweatshirts     143     143
# Men_Hosen                     174     174
# Men_Schuhe                    124     124
# Men_T-Shirts                  244     244
# Women_Accessoires             700     700
# Women_Bademode                223     223
# Women_Beauty                  669     669
# Women_Cardigans-&-Pullover    281     281
# Women_Hemden-&-Blusen         373     373
# Women_Hoodies-&-Sweatshirts   203     203
# Women_Hosen                   545     545
# Women_Jacken-&-Mäntel         275     275
# Women_Jeans                   466     466
# Women_Kleider                 646     646
# Women_Nachtwäsche             260     260
# Women_Röcke                   151     151
# Women_Schuhe                  266     266
# Women_Shirts-&-Tops           568     568
# Women_Shorts                  215     215
# Women_Socken-&-Strumpfhosen   126     126
# Women_Sportbekleidung         256     256
# Women_Unterwäsche             817     817

# %%
items_u.shape
# Out:
# (14456, 7)

# %%
print(f"Final dataframe with {items_u.shape[0]:,} products across {items_u['Category_Name'].nunique()} categories")
# Out:
# Final dataframe with 14,456 products across 31 categories

# %%
items_u.head()
# Out:
#          Code                      Name Img_Ext  Parent_Category Top_Category  \
# 0  1071498001             Cut-out-Shirt    .jpg              0.0        Women
# 1  1069183001  Kurzes Shirt mit Cut-out    .jpg              0.0        Women
# 4  1069183002  Kurzes Shirt mit Cut-out    .jpg              0.0        Women
# 5  1021919001     Pullover mit Cut-outs    .jpg              0.0        Women
# 6  1062813001                   Tanktop    .jpg              0.0        Women
#
#   Parent_Category_Name        Category_Name
# 0        Shirts & Tops  Women_Shirts-&-Tops
# 1        Shirts & Tops  Women_Shirts-&-Tops
# 4        Shirts & Tops  Women_Shirts-&-Tops
# 5        Shirts & Tops  Women_Shirts-&-Tops
# 6        Shirts & Tops  Women_Shirts-&-Tops

# %%
items_u.to_parquet(hnm_file_format.format('Final_Input_Df'))
