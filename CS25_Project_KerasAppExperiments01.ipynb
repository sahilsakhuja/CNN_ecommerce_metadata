# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle

# %%
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image, image_dataset_from_directory
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.models import Model
from tensorflow.keras.metrics import Accuracy

# %%
# Enable/Disable Eager Execution
# Reference: https://www.tensorflow.org/guide/eager
# TensorFlow's eager execution is an imperative programming environment that evaluates operations immediately, 
# without building graphs

#tf.compat.v1.disable_eager_execution()
#tf.compat.v1.enable_eager_execution()

print("tensorflow version", tf.__version__)
print("keras version", tf.keras.__version__)
print("Eager Execution Enabled:", tf.executing_eagerly())

# Get the number of replicas 
strategy = tf.distribute.MirroredStrategy()
print("Number of replicas:", strategy.num_replicas_in_sync)

devices = tf.config.experimental.get_visible_devices()
print("Devices:", devices)
print(tf.config.experimental.list_logical_devices('GPU'))

print("GPU Available: ", tf.config.list_physical_devices('GPU'))
print("All Physical Devices", tf.config.list_physical_devices())

# Better performance with the tf.data API
# Reference: https://www.tensorflow.org/guide/data_performance
AUTOTUNE = tf.data.experimental.AUTOTUNE
# Out:
# tensorflow version 2.8.0
# keras version 2.8.0
# Eager Execution Enabled: True
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Number of replicas: 1
# Devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# GPU Available:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# All Physical Devices [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
hnm_file_format = '/content/drive/MyDrive/Temporary/CS25_Project/HnM_{}.parquet'
hnm_img_format = '/content/drive/MyDrive/Temporary/CS25_Project/images/HnM/{}'

# %%
# folder names
hnm_img_final = '/content/drive/MyDrive/Temporary/CS25_Project/images_final/HnM/'
hnm_img_final_top = '/content/drive/MyDrive/Temporary/CS25_Project/images_final'

# %%
model_wts_path = '/content/drive/MyDrive/Temporary/CS25_Project/'
model_hist_path = '/content/drive/MyDrive/Temporary/CS25_Project/'

# %%
# get list of images
# imgs = [k for k in os.listdir(hnm_img_final)]

# %%
# print(f"We have a total of {len(imgs):,} images")
# Out:
# We have a total of 14,456 images

# %% [markdown]
# Getting base model and training the model with our df

# %%
## load the data frame
df = pd.read_parquet(hnm_file_format.format('Final_Input_Df'))
df['Category_Name'] = df['Category_Name'].astype('category')
df['Category_Name_Code'] = df['Category_Name'].cat.codes

# %%
df[['Category_Name', 'Category_Name_Code']].drop_duplicates().sort_values(by='Category_Name_Code')
# Out:
#                      Category_Name  Category_Name_Code
# 16681             Baby_Accessoires                   0
# 15042                Baby_Kleidung                   1
# 22239             Kids_Accessoires                   2
# 16885                Kids_Kleidung                   3
# 21916                 Kids_Outdoor                   4
# 22548                  Kids_Schuhe                   5
# 14065              Men_Accessoires                   6
# 12335     Men_Cardigans-&-Pullover                   7
# 12481                   Men_Hemden                   8
# 12120    Men_Hoodies-&-Sweatshirts                   9
# 13273                    Men_Hosen                  10
# 13934                   Men_Schuhe                  11
# 12682                 Men_T-Shirts                  12
# 7361             Women_Accessoires                  13
# 8114                Women_Bademode                  14
# 10805                 Women_Beauty                  15
# 2503    Women_Cardigans-&-Pullover                  16
# 2085         Women_Hemden-&-Blusen                  17
# 11530  Women_Hoodies-&-Sweatshirts                  18
# 3281                   Women_Hosen                  19
# 2854         Women_Jacken-&-Mäntel                  20
# 4195                   Women_Jeans                  21
# 5524                 Women_Kleider                  22
# 9781             Women_Nachtwäsche                  23
# 5194                   Women_Röcke                  24
# 7010                  Women_Schuhe                  25
# 0              Women_Shirts-&-Tops                  26
# 4878                  Women_Shorts                  27
# 10041  Women_Socken-&-Strumpfhosen                  28
# 10214        Women_Sportbekleidung                  29
# 8349             Women_Unterwäsche                  30

# %%
# sort by the code since thats how flow from directory would work
df = df.sort_values(by='Code')
df.head()
# Out:
#             Code                   Name Img_Ext  Parent_Category Top_Category  \
# 9842  0107727001  Bademantel aus Leinen    .jpg             18.0        Women
# 9844  0107727002  Bademantel aus Leinen    .jpg             18.0        Women
# 9839  0107727021  Bademantel aus Leinen    .jpg             18.0        Women
# 9832  0107727061  Bademantel aus Leinen    .jpg             18.0        Women
# 9837  0107727062  Bademantel aus Leinen    .jpg             18.0        Women
#
#      Parent_Category_Name      Category_Name  Category_Name_Code
# 9842          Nachtwäsche  Women_Nachtwäsche                  23
# 9844          Nachtwäsche  Women_Nachtwäsche                  23
# 9839          Nachtwäsche  Women_Nachtwäsche                  23
# 9832          Nachtwäsche  Women_Nachtwäsche                  23
# 9837          Nachtwäsche  Women_Nachtwäsche                  23

# %%
y_train = df['Category_Name_Code'].values
nr_labels = len(np.unique(y_train))

# %%
input_shape = (256, 256, 3)

# %%
random_seed = 109

images_train = image_dataset_from_directory(
    hnm_img_final_top,
    labels = list(y_train),
    subset = 'training',
    validation_split = 0.6,
    seed = random_seed,
    batch_size=256,
    image_size=input_shape[:2]
)

images_val = image_dataset_from_directory(
    hnm_img_final_top,
    labels = list(y_train),
    subset = 'validation',
    validation_split = 0.6,
    seed = random_seed,
    batch_size=256,
    image_size=input_shape[:2]
)

# %%
models = {
    'Resnet50': {
        'model': 'ResNet50',
        'preprocess': 'resnet50',
    },
    'VGG19': {
        'model': 'VGG19',
        'preprocess': 'vgg19',
    },
    'InceptionV3': {
        'model': 'InceptionV3',
        'preprocess': 'inception_v3',
    },
    'MobileNetV2': {
        'model': 'MobileNetV2',
        'preprocess': 'mobilenet_v2',
    },
    'EfficientNetB3': {
        'model': 'EfficientNetB3',
        'preprocess': 'efficientnet',
    },
}

# %%
# add a global spatial average pooling layer

epochs = 50
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)

model_hists = {}

for model_name, model_params in models.items():
  if os.path.exists(f"{model_hist_path}{model_name}.pkl"):
    # we've completed this one... let's keep going
    print(f"Skipping {model_name} since this is already completed.")
    continue

  print(f"Starting training with {model_name}")
  inputs = tf.keras.layers.Input(shape=input_shape)
  # We make sure that the base_model is running in inference mode here,
  # by passing `training=False`. This is important for fine-tuning, as you will
  # learn in a few paragraphs.
  base_model = eval('tf.keras.applications.' + model_params['model'])(include_top=False, input_shape=input_shape, pooling='avg')
  # x = base_model(inputs, training=False)
  x = base_model.output
  # x = base_model.get_layer('avg_pool').output
  # x = GlobalAveragePooling2D()(x)
  # let's add a fully-connected layer
  x = Dense(256, activation='relu')(x)
  x = Dropout(0.5)(x)
  x = Dense(256, activation='relu')(x)
  # and a logistic layer -- with classes = nr_labels
  predictions = Dense(nr_labels, activation='softmax')(x)

  # this is the model we will train
  model = Model(inputs=base_model.input, outputs=predictions)

  # first: train only the top layers (which were randomly initialized)
  # i.e. freeze all convolutional InceptionV3 layers
  for layer in base_model.layers:
      layer.trainable = False

  # compile the model (should be done *after* setting layers to non-trainable)
  model.compile(optimizer=Adam(learning_rate=1e-4), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

  # model.compile(optimizer=Adam(learning_rate=1e-3), loss=SparseCategoricalCrossentropy(), metrics=[Accuracy])

  # preprocess train and test sets if required
  if model_params.get('preprocess', False):
    images_train_f = images_train.map(lambda x, y: ( eval('tf.keras.applications.' + model_params['preprocess'] + '.preprocess_input')(x), y ), num_parallel_calls=AUTOTUNE)
    images_val_f = images_val.map(lambda x, y: ( eval('tf.keras.applications.' + model_params['preprocess'] + '.preprocess_input')(x), y ), num_parallel_calls=AUTOTUNE)
  else:
    images_train_f = images_train
    images_val_f = images_val

  images_train_f = images_train_f.prefetch(1)
  images_val_f = images_val_f.prefetch(1)

  print(f"All ready! Starting fit!")
  # model.summary()
  hist = model.fit(
      images_train_f,
      batch_size=256,
      epochs=epochs,
      validation_data=images_val_f,
      verbose=True,
      callbacks=[es]
    )
  
  model.save_weights(f"{model_wts_path}{model_name}.h5")
  
  min_loss_idx = np.argmin(hist.history['val_loss'])

  print(f"Completed training of {model_name} with max validation accuracy: {hist.history['val_accuracy'][min_loss_idx]:.2%} at Epoch Nr {min_loss_idx+1}")

  model_hists[model_name] = hist
  with open(f"{model_hist_path}{model_name}.pkl", 'wb') as file_pi:
      pickle.dump(hist.history, file_pi)
# Out:
# Skipping Resnet50 since this is already completed.
# Skipping VGG19 since this is already completed.
# Starting training with InceptionV3
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 0s 0us/step
# 87924736/87910968 [==============================] - 0s 0us/step
# All ready! Starting fit!
# Epoch 1/50
# 23/23 [==============================] - 236s 2s/step - loss: 3.0222 - accuracy: 0.2488 - val_loss: 2.6651 - val_accuracy: 0.3022
# Epoch 2/50
# 23/23 [==============================] - 50s 2s/step - loss: 2.6222 - accuracy: 0.3211 - val_loss: 2.3702 - val_accuracy: 0.3615
# Epoch 3/50
# 23/23 [==============================] - 50s 2s/step - loss: 2.3519 - accuracy: 0.3714 - val_loss: 2.1262 - val_accuracy: 0.4150
# Epoch 4/50
# 23/23 [==============================] - 50s 2s/step - loss: 2.1431 - accuracy: 0.4067 - val_loss: 1.9236 - val_accuracy: 0.4566
# Epoch 5/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.9632 - accuracy: 0.4363 - val_loss: 1.7769 - val_accuracy: 0.4892
# Epoch 6/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.8086 - accuracy: 0.4674 - val_loss: 1.6451 - val_accuracy: 0.5103
# Epoch 7/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.6795 - accuracy: 0.4978 - val_loss: 1.5370 - val_accuracy: 0.5284
# Epoch 8/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.6197 - accuracy: 0.5020 - val_loss: 1.4667 - val_accuracy: 0.5403
# Epoch 9/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.5254 - accuracy: 0.5238 - val_loss: 1.4068 - val_accuracy: 0.5571
# Epoch 10/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.4599 - accuracy: 0.5388 - val_loss: 1.3546 - val_accuracy: 0.5699
# Epoch 11/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.4015 - accuracy: 0.5464 - val_loss: 1.3164 - val_accuracy: 0.5787
# Epoch 12/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.3566 - accuracy: 0.5604 - val_loss: 1.2809 - val_accuracy: 0.5872
# Epoch 13/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.3167 - accuracy: 0.5718 - val_loss: 1.2530 - val_accuracy: 0.5911
# Epoch 14/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.2711 - accuracy: 0.5819 - val_loss: 1.2222 - val_accuracy: 0.5975
# Epoch 15/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.2283 - accuracy: 0.5962 - val_loss: 1.2000 - val_accuracy: 0.6069
# Epoch 16/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.1938 - accuracy: 0.6006 - val_loss: 1.1800 - val_accuracy: 0.6137
# Epoch 17/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.1849 - accuracy: 0.6057 - val_loss: 1.1585 - val_accuracy: 0.6164
# Epoch 18/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.1411 - accuracy: 0.6218 - val_loss: 1.1437 - val_accuracy: 0.6186
# Epoch 19/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.1255 - accuracy: 0.6237 - val_loss: 1.1348 - val_accuracy: 0.6209
# Epoch 20/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.1042 - accuracy: 0.6244 - val_loss: 1.1126 - val_accuracy: 0.6322
# Epoch 21/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.0645 - accuracy: 0.6415 - val_loss: 1.0991 - val_accuracy: 0.6333
# Epoch 22/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.0569 - accuracy: 0.6486 - val_loss: 1.0901 - val_accuracy: 0.6347
# Epoch 23/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.0197 - accuracy: 0.6542 - val_loss: 1.0773 - val_accuracy: 0.6399
# Epoch 24/50
# 23/23 [==============================] - 50s 2s/step - loss: 1.0161 - accuracy: 0.6545 - val_loss: 1.0646 - val_accuracy: 0.6443
# Epoch 25/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.9978 - accuracy: 0.6692 - val_loss: 1.0565 - val_accuracy: 0.6446
# Epoch 26/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.9712 - accuracy: 0.6723 - val_loss: 1.0475 - val_accuracy: 0.6470
# Epoch 27/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.9484 - accuracy: 0.6770 - val_loss: 1.0359 - val_accuracy: 0.6524
# Epoch 28/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.9361 - accuracy: 0.6842 - val_loss: 1.0359 - val_accuracy: 0.6480
# Epoch 29/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.9057 - accuracy: 0.6970 - val_loss: 1.0283 - val_accuracy: 0.6514
# Epoch 30/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.8962 - accuracy: 0.6925 - val_loss: 1.0127 - val_accuracy: 0.6534
# Epoch 31/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.8867 - accuracy: 0.6936 - val_loss: 1.0069 - val_accuracy: 0.6591
# Epoch 32/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.8710 - accuracy: 0.7104 - val_loss: 1.0011 - val_accuracy: 0.6582
# Epoch 33/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.8546 - accuracy: 0.7145 - val_loss: 0.9940 - val_accuracy: 0.6615
# Epoch 34/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.8500 - accuracy: 0.7100 - val_loss: 0.9843 - val_accuracy: 0.6661
# Epoch 35/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.8273 - accuracy: 0.7225 - val_loss: 0.9813 - val_accuracy: 0.6655
# Epoch 36/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.8163 - accuracy: 0.7206 - val_loss: 0.9760 - val_accuracy: 0.6697
# Epoch 37/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.8073 - accuracy: 0.7263 - val_loss: 0.9750 - val_accuracy: 0.6675
# Epoch 38/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.7822 - accuracy: 0.7347 - val_loss: 0.9661 - val_accuracy: 0.6698
# Epoch 39/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.7788 - accuracy: 0.7334 - val_loss: 0.9613 - val_accuracy: 0.6734
# Epoch 40/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.7681 - accuracy: 0.7441 - val_loss: 0.9561 - val_accuracy: 0.6755
# Epoch 41/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.7409 - accuracy: 0.7467 - val_loss: 0.9576 - val_accuracy: 0.6719
# Epoch 42/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.7392 - accuracy: 0.7493 - val_loss: 0.9587 - val_accuracy: 0.6742
# Epoch 43/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.7393 - accuracy: 0.7472 - val_loss: 0.9451 - val_accuracy: 0.6746
# Epoch 44/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.7188 - accuracy: 0.7564 - val_loss: 0.9441 - val_accuracy: 0.6790
# Epoch 45/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.7053 - accuracy: 0.7641 - val_loss: 0.9416 - val_accuracy: 0.6781
# Epoch 46/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.7015 - accuracy: 0.7570 - val_loss: 0.9331 - val_accuracy: 0.6792
# Epoch 47/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.6787 - accuracy: 0.7705 - val_loss: 0.9325 - val_accuracy: 0.6814
# Epoch 48/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.6743 - accuracy: 0.7714 - val_loss: 0.9327 - val_accuracy: 0.6807
# Epoch 49/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.6615 - accuracy: 0.7781 - val_loss: 0.9266 - val_accuracy: 0.6835
# Epoch 50/50
# 23/23 [==============================] - 50s 2s/step - loss: 0.6680 - accuracy: 0.7740 - val_loss: 0.9240 - val_accuracy: 0.6837
# Completed training of InceptionV3 with max validation accuracy: 68.37% at Epoch Nr 50
# Starting training with MobileNetV2
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step
# All ready! Starting fit!
# Epoch 1/50
# 23/23 [==============================] - 52s 2s/step - loss: 3.1557 - accuracy: 0.2006 - val_loss: 2.7754 - val_accuracy: 0.2942
# Epoch 2/50
# 23/23 [==============================] - 44s 2s/step - loss: 2.7015 - accuracy: 0.3227 - val_loss: 2.4594 - val_accuracy: 0.3676
# Epoch 3/50
# 23/23 [==============================] - 44s 2s/step - loss: 2.4301 - accuracy: 0.3764 - val_loss: 2.1870 - val_accuracy: 0.4016
# Epoch 4/50
# 23/23 [==============================] - 45s 2s/step - loss: 2.1799 - accuracy: 0.4169 - val_loss: 1.9470 - val_accuracy: 0.4475
# Epoch 5/50
# 23/23 [==============================] - 45s 2s/step - loss: 1.9912 - accuracy: 0.4442 - val_loss: 1.7693 - val_accuracy: 0.4794
# Epoch 6/50
# 23/23 [==============================] - 45s 2s/step - loss: 1.8260 - accuracy: 0.4702 - val_loss: 1.6239 - val_accuracy: 0.5144
# Epoch 7/50
# 23/23 [==============================] - 44s 2s/step - loss: 1.6890 - accuracy: 0.4980 - val_loss: 1.5076 - val_accuracy: 0.5472
# Epoch 8/50
# 23/23 [==============================] - 44s 2s/step - loss: 1.6015 - accuracy: 0.5158 - val_loss: 1.4141 - val_accuracy: 0.5652
# Epoch 9/50
# 23/23 [==============================] - 44s 2s/step - loss: 1.5030 - accuracy: 0.5405 - val_loss: 1.3411 - val_accuracy: 0.5767
# Epoch 10/50
# 23/23 [==============================] - 44s 2s/step - loss: 1.4320 - accuracy: 0.5494 - val_loss: 1.2861 - val_accuracy: 0.5916
# Epoch 11/50
# 23/23 [==============================] - 44s 2s/step - loss: 1.3724 - accuracy: 0.5691 - val_loss: 1.2382 - val_accuracy: 0.5976
# Epoch 12/50
# 23/23 [==============================] - 44s 2s/step - loss: 1.3118 - accuracy: 0.5822 - val_loss: 1.1911 - val_accuracy: 0.6097
# Epoch 13/50
# 23/23 [==============================] - 44s 2s/step - loss: 1.2584 - accuracy: 0.5959 - val_loss: 1.1589 - val_accuracy: 0.6190
# Epoch 14/50
# 23/23 [==============================] - 44s 2s/step - loss: 1.2169 - accuracy: 0.6123 - val_loss: 1.1312 - val_accuracy: 0.6249
# Epoch 15/50
# 23/23 [==============================] - 44s 2s/step - loss: 1.1633 - accuracy: 0.6239 - val_loss: 1.1043 - val_accuracy: 0.6345
# Epoch 16/50
# 23/23 [==============================] - 44s 2s/step - loss: 1.1410 - accuracy: 0.6261 - val_loss: 1.0788 - val_accuracy: 0.6446
# Epoch 17/50
# 23/23 [==============================] - 45s 2s/step - loss: 1.1154 - accuracy: 0.6393 - val_loss: 1.0605 - val_accuracy: 0.6471
# Epoch 18/50
# 23/23 [==============================] - 44s 2s/step - loss: 1.0848 - accuracy: 0.6370 - val_loss: 1.0420 - val_accuracy: 0.6538
# Epoch 19/50
# 23/23 [==============================] - 45s 2s/step - loss: 1.0530 - accuracy: 0.6476 - val_loss: 1.0261 - val_accuracy: 0.6565
# Epoch 20/50
# 23/23 [==============================] - 44s 2s/step - loss: 1.0214 - accuracy: 0.6645 - val_loss: 1.0105 - val_accuracy: 0.6615
# Epoch 21/50
# 23/23 [==============================] - 45s 2s/step - loss: 0.9922 - accuracy: 0.6697 - val_loss: 0.9986 - val_accuracy: 0.6656
# Epoch 22/50
# 23/23 [==============================] - 45s 2s/step - loss: 0.9852 - accuracy: 0.6711 - val_loss: 0.9825 - val_accuracy: 0.6684
# Epoch 23/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.9570 - accuracy: 0.6799 - val_loss: 0.9730 - val_accuracy: 0.6721
# Epoch 24/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.9362 - accuracy: 0.6910 - val_loss: 0.9622 - val_accuracy: 0.6751
# Epoch 25/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.9162 - accuracy: 0.6972 - val_loss: 0.9522 - val_accuracy: 0.6783
# Epoch 26/50
# 23/23 [==============================] - 59s 2s/step - loss: 0.9028 - accuracy: 0.7010 - val_loss: 0.9422 - val_accuracy: 0.6802
# Epoch 27/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.8724 - accuracy: 0.7053 - val_loss: 0.9356 - val_accuracy: 0.6834
# Epoch 28/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.8674 - accuracy: 0.7105 - val_loss: 0.9260 - val_accuracy: 0.6873
# Epoch 29/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.8584 - accuracy: 0.7121 - val_loss: 0.9204 - val_accuracy: 0.6882
# Epoch 30/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.8446 - accuracy: 0.7199 - val_loss: 0.9126 - val_accuracy: 0.6903
# Epoch 31/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.8266 - accuracy: 0.7221 - val_loss: 0.9019 - val_accuracy: 0.6928
# Epoch 32/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.8173 - accuracy: 0.7259 - val_loss: 0.8992 - val_accuracy: 0.6965
# Epoch 33/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.7929 - accuracy: 0.7270 - val_loss: 0.8925 - val_accuracy: 0.6969
# Epoch 34/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.7940 - accuracy: 0.7334 - val_loss: 0.8917 - val_accuracy: 0.6961
# Epoch 35/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.7717 - accuracy: 0.7427 - val_loss: 0.8826 - val_accuracy: 0.7016
# Epoch 36/50
# 23/23 [==============================] - 45s 2s/step - loss: 0.7661 - accuracy: 0.7422 - val_loss: 0.8766 - val_accuracy: 0.7032
# Epoch 37/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.7396 - accuracy: 0.7501 - val_loss: 0.8724 - val_accuracy: 0.7041
# Epoch 38/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.7324 - accuracy: 0.7564 - val_loss: 0.8673 - val_accuracy: 0.7064
# Epoch 39/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.7297 - accuracy: 0.7541 - val_loss: 0.8626 - val_accuracy: 0.7077
# Epoch 40/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.7123 - accuracy: 0.7602 - val_loss: 0.8595 - val_accuracy: 0.7064
# Epoch 41/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.6954 - accuracy: 0.7672 - val_loss: 0.8551 - val_accuracy: 0.7089
# Epoch 42/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.6875 - accuracy: 0.7664 - val_loss: 0.8513 - val_accuracy: 0.7113
# Epoch 43/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.6799 - accuracy: 0.7740 - val_loss: 0.8458 - val_accuracy: 0.7111
# Epoch 44/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.6689 - accuracy: 0.7750 - val_loss: 0.8448 - val_accuracy: 0.7146
# Epoch 45/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.6657 - accuracy: 0.7736 - val_loss: 0.8407 - val_accuracy: 0.7159
# Epoch 46/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.6518 - accuracy: 0.7773 - val_loss: 0.8376 - val_accuracy: 0.7142
# Epoch 47/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.6454 - accuracy: 0.7838 - val_loss: 0.8349 - val_accuracy: 0.7191
# Epoch 48/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.6255 - accuracy: 0.7878 - val_loss: 0.8350 - val_accuracy: 0.7160
# Epoch 49/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.6232 - accuracy: 0.7889 - val_loss: 0.8299 - val_accuracy: 0.7173
# Epoch 50/50
# 23/23 [==============================] - 44s 2s/step - loss: 0.6133 - accuracy: 0.7906 - val_loss: 0.8272 - val_accuracy: 0.7172
# Completed training of MobileNetV2 with max validation accuracy: 71.72% at Epoch Nr 50
# Starting training with EfficientNetB3
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941888/43941136 [==============================] - 1s 0us/step
# 43950080/43941136 [==============================] - 1s 0us/step
# All ready! Starting fit!
# Epoch 1/50
# 23/23 [==============================] - 89s 3s/step - loss: 3.1119 - accuracy: 0.2286 - val_loss: 2.7749 - val_accuracy: 0.3059
# Epoch 2/50
# 23/23 [==============================] - 69s 3s/step - loss: 2.6805 - accuracy: 0.3135 - val_loss: 2.4599 - val_accuracy: 0.3584
# Epoch 3/50
# 23/23 [==============================] - 69s 3s/step - loss: 2.4146 - accuracy: 0.3759 - val_loss: 2.1879 - val_accuracy: 0.4072
# Epoch 4/50
# 23/23 [==============================] - 70s 3s/step - loss: 2.1760 - accuracy: 0.4162 - val_loss: 1.9524 - val_accuracy: 0.4534
# Epoch 5/50
# 23/23 [==============================] - 70s 3s/step - loss: 1.9763 - accuracy: 0.4461 - val_loss: 1.7683 - val_accuracy: 0.4903
# Epoch 6/50
# 23/23 [==============================] - 70s 3s/step - loss: 1.8172 - accuracy: 0.4762 - val_loss: 1.6230 - val_accuracy: 0.5207
# Epoch 7/50
# 23/23 [==============================] - 70s 3s/step - loss: 1.6854 - accuracy: 0.4992 - val_loss: 1.5033 - val_accuracy: 0.5416
# Epoch 8/50
# 23/23 [==============================] - 70s 3s/step - loss: 1.5780 - accuracy: 0.5186 - val_loss: 1.4072 - val_accuracy: 0.5637
# Epoch 9/50
# 23/23 [==============================] - 70s 3s/step - loss: 1.4943 - accuracy: 0.5378 - val_loss: 1.3296 - val_accuracy: 0.5810
# Epoch 10/50
# 23/23 [==============================] - 70s 3s/step - loss: 1.4288 - accuracy: 0.5466 - val_loss: 1.2654 - val_accuracy: 0.5967
# Epoch 11/50
# 23/23 [==============================] - 71s 3s/step - loss: 1.3638 - accuracy: 0.5658 - val_loss: 1.2183 - val_accuracy: 0.6071
# Epoch 12/50
# 23/23 [==============================] - 70s 3s/step - loss: 1.3126 - accuracy: 0.5751 - val_loss: 1.1742 - val_accuracy: 0.6174
# Epoch 13/50
# 23/23 [==============================] - 70s 3s/step - loss: 1.2652 - accuracy: 0.5883 - val_loss: 1.1403 - val_accuracy: 0.6292
# Epoch 14/50
# 23/23 [==============================] - 70s 3s/step - loss: 1.2286 - accuracy: 0.5942 - val_loss: 1.1127 - val_accuracy: 0.6386
# Epoch 15/50
# 23/23 [==============================] - 69s 3s/step - loss: 1.1919 - accuracy: 0.6030 - val_loss: 1.0835 - val_accuracy: 0.6445
# Epoch 16/50
# 23/23 [==============================] - 70s 3s/step - loss: 1.1779 - accuracy: 0.6037 - val_loss: 1.0623 - val_accuracy: 0.6546
# Epoch 17/50
# 23/23 [==============================] - 70s 3s/step - loss: 1.1507 - accuracy: 0.6206 - val_loss: 1.0419 - val_accuracy: 0.6580
# Epoch 18/50
# 23/23 [==============================] - 70s 3s/step - loss: 1.1155 - accuracy: 0.6161 - val_loss: 1.0227 - val_accuracy: 0.6608
# Epoch 19/50
# 23/23 [==============================] - 69s 3s/step - loss: 1.0916 - accuracy: 0.6284 - val_loss: 1.0106 - val_accuracy: 0.6662
# Epoch 20/50
# 23/23 [==============================] - 69s 3s/step - loss: 1.0605 - accuracy: 0.6386 - val_loss: 0.9942 - val_accuracy: 0.6707
# Epoch 21/50
# 23/23 [==============================] - 70s 3s/step - loss: 1.0381 - accuracy: 0.6497 - val_loss: 0.9794 - val_accuracy: 0.6746
# Epoch 22/50
# 23/23 [==============================] - 70s 3s/step - loss: 1.0214 - accuracy: 0.6531 - val_loss: 0.9643 - val_accuracy: 0.6792
# Epoch 23/50
# 23/23 [==============================] - 70s 3s/step - loss: 1.0086 - accuracy: 0.6585 - val_loss: 0.9565 - val_accuracy: 0.6821
# Epoch 24/50
# 23/23 [==============================] - 69s 3s/step - loss: 1.0002 - accuracy: 0.6587 - val_loss: 0.9457 - val_accuracy: 0.6821
# Epoch 25/50
# 23/23 [==============================] - 70s 3s/step - loss: 0.9674 - accuracy: 0.6687 - val_loss: 0.9343 - val_accuracy: 0.6871
# Epoch 26/50
# 23/23 [==============================] - 70s 3s/step - loss: 0.9607 - accuracy: 0.6685 - val_loss: 0.9204 - val_accuracy: 0.6903
# Epoch 27/50
# 23/23 [==============================] - 69s 3s/step - loss: 0.9484 - accuracy: 0.6756 - val_loss: 0.9180 - val_accuracy: 0.6910
# Epoch 28/50
# 23/23 [==============================] - 70s 3s/step - loss: 0.9294 - accuracy: 0.6808 - val_loss: 0.9041 - val_accuracy: 0.6949
# Epoch 29/50
# 23/23 [==============================] - 69s 3s/step - loss: 0.9195 - accuracy: 0.6872 - val_loss: 0.9032 - val_accuracy: 0.6934
# Epoch 30/50
# 23/23 [==============================] - 69s 3s/step - loss: 0.9018 - accuracy: 0.6908 - val_loss: 0.8900 - val_accuracy: 0.6971
# Epoch 31/50
# 23/23 [==============================] - 70s 3s/step - loss: 0.9007 - accuracy: 0.6929 - val_loss: 0.8807 - val_accuracy: 0.6995
# Epoch 32/50
# 23/23 [==============================] - 70s 3s/step - loss: 0.8828 - accuracy: 0.6967 - val_loss: 0.8760 - val_accuracy: 0.6998
# Epoch 33/50
# 23/23 [==============================] - 69s 3s/step - loss: 0.8751 - accuracy: 0.7083 - val_loss: 0.8712 - val_accuracy: 0.7030
# Epoch 34/50
# 23/23 [==============================] - 69s 3s/step - loss: 0.8822 - accuracy: 0.7003 - val_loss: 0.8651 - val_accuracy: 0.7053
# Epoch 35/50
# 23/23 [==============================] - 70s 3s/step - loss: 0.8593 - accuracy: 0.7019 - val_loss: 0.8601 - val_accuracy: 0.7061
# Epoch 36/50
# 23/23 [==============================] - 70s 3s/step - loss: 0.8392 - accuracy: 0.7159 - val_loss: 0.8527 - val_accuracy: 0.7060
# Epoch 37/50
# 23/23 [==============================] - 70s 3s/step - loss: 0.8259 - accuracy: 0.7219 - val_loss: 0.8450 - val_accuracy: 0.7083
# Epoch 38/50
# 23/23 [==============================] - 70s 3s/step - loss: 0.8301 - accuracy: 0.7180 - val_loss: 0.8437 - val_accuracy: 0.7098
# Epoch 39/50
# 23/23 [==============================] - 70s 3s/step - loss: 0.7968 - accuracy: 0.7259 - val_loss: 0.8355 - val_accuracy: 0.7132
# Epoch 40/50
# 23/23 [==============================] - 70s 3s/step - loss: 0.7949 - accuracy: 0.7230 - val_loss: 0.8330 - val_accuracy: 0.7111
# Epoch 41/50
# 23/23 [==============================] - 69s 3s/step - loss: 0.7899 - accuracy: 0.7290 - val_loss: 0.8246 - val_accuracy: 0.7147
# Epoch 42/50
# 23/23 [==============================] - 70s 3s/step - loss: 0.7906 - accuracy: 0.7330 - val_loss: 0.8185 - val_accuracy: 0.7190
# Epoch 43/50
# 23/23 [==============================] - 69s 3s/step - loss: 0.7766 - accuracy: 0.7349 - val_loss: 0.8214 - val_accuracy: 0.7158
# Epoch 44/50
# 23/23 [==============================] - 70s 3s/step - loss: 0.7535 - accuracy: 0.7377 - val_loss: 0.8138 - val_accuracy: 0.7198
# Epoch 45/50
# 23/23 [==============================] - 70s 3s/step - loss: 0.7735 - accuracy: 0.7346 - val_loss: 0.8115 - val_accuracy: 0.7197
# Epoch 46/50
# 23/23 [==============================] - 69s 3s/step - loss: 0.7598 - accuracy: 0.7408 - val_loss: 0.8063 - val_accuracy: 0.7236
# Epoch 47/50
# 23/23 [==============================] - 69s 3s/step - loss: 0.7408 - accuracy: 0.7403 - val_loss: 0.8021 - val_accuracy: 0.7220
# Epoch 48/50
# 23/23 [==============================] - 69s 3s/step - loss: 0.7508 - accuracy: 0.7430 - val_loss: 0.8001 - val_accuracy: 0.7239
# Epoch 49/50
# 23/23 [==============================] - 69s 3s/step - loss: 0.7324 - accuracy: 0.7468 - val_loss: 0.7927 - val_accuracy: 0.7279
# Epoch 50/50
# 23/23 [==============================] - 69s 3s/step - loss: 0.7079 - accuracy: 0.7513 - val_loss: 0.7868 - val_accuracy: 0.7297
# Completed training of EfficientNetB3 with max validation accuracy: 72.97% at Epoch Nr 50
